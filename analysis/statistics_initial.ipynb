# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from analysis import plot_acc, data_acc, plot_order, result_order, data_order

# %% [markdown]
# ## Accuracy

# %%
data_acc(
    "../training_log", 
    [
    # both lst & comm: large variation 
    # seed 2230: comm acc ~ 1
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden32*_lst.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden32*_spk.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden32*_comm.txt",
    # both comm: large variation 
    # seed 2231: comm acc ~ 1;     # seed 2238,2233: comm acc ~ 1 (40 epochs)
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden64*_lst.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden64*_spk.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden64*_comm.txt",
    #===========not good
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden80*_lst.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden80*_spk.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden80*_comm.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden96*_lst.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden96*_spk.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden96*_comm.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden112*_lst.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden112*_spk.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden112*_comm.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden128*_lst.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden128*_spk.txt",
    # "/train_langinitial_simple_split*_spkhidden64_lsthidden128*_comm.txt",
     ],
    plt_one=True 
    # plt_one=False 
     )

# %% [markdown]
# # Word order preferences

# %%
folder_path = "../dump"
initial_result = pd.read_csv('initial_result_simple.csv')

data_order(folder_path, initial_result, 
           [
   #  "langinitial_simple_split*_spkhidden64_lsthidden32*_spk",
   #  "langinitial_simple_split*_spkhidden64_lsthidden32*_comm" # SO_SM 50%, SO_OM dominant # # _seed2230
#     "langinitial_simple_split*_spkhidden64_lsthidden64*_spk",
   #  "langinitial_simple_split*_spkhidden64_lsthidden64*_seed2231_comm" # 
    "langinitial_simple_split*_spkhidden64_lsthidden96*_comm" # 
            ], 
         #   plt_one=True
           plt_one=False
           )
